# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pandas.read_csv('Datos/winequality-red.csv') #(,sep='&') para separar datos en el csv por &
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.index #nombres de los rengoles
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
df.values #guarda en un arreglo
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
print(df['pH'].values) #sólo los valores de la variable 'pH'
# Out:
# [3.51 3.2  3.26 ... 3.42 3.57 3.39]

# %%
print(df[['pH', 'quality']].values)
# Out:
# [[3.51 5.  ]
#  [3.2  5.  ]
#  [3.26 5.  ]
#  ...
#  [3.42 6.  ]
#  [3.57 5.  ]
#  [3.39 6.  ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality'].describe() #calcula
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
for c in df.columns:
    print(c)
    print(df[c].describe(),'\n')
# Out:
# fixed acidity
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64
#
# volatile acidity
# count    1599.000000
# mean        0.527821
# std         0.179060
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64
#
# citric acid
# count    1599.000000
# mean        0.270976
# std         0.194801
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64
#
# residual sugar
# count    1599.000000
# mean        2.538806
# std         1.409928
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64
#
# chlorides
# count    1599.000000
# ...

# %%
nfeatures = len(df.columns)
m = 10 #min,max,mean,std...,maxN
values = np.zeros((m, nfeatures)) 
columns = df.columns
index = ['min','max','mean','std','Q1','Q2','Q3', 'IQR','minN','maxN']

for i,column in enumerate(df.columns):
    values[0,i] = np.min( df[column].values )
    values[1,i] = np.max( df[column].values )
    values[2,i] = np.mean( df[column].values )
    values[3,i] = np.std( df[column].values )
    values[4,i] = np.percentile( df[column].values,25 )
    values[5,i] = np.percentile( df[column].values,50 )
    values[6,i] = np.percentile( df[column].values,75 )
    values[7,i] = values[6,i] - values[4,i]
    values[8,i] = values[4,i] - 1.5*values[7,i]
    values[9,i] = values[6,i] + 1.5*values[7,i]

    
dfs = pandas.DataFrame(values, columns=columns, index=index)
dfs.to_csv('winequality_statistics')
dfs
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# min        4.600000          0.120000     0.000000        0.900000   0.012000
# max       15.900000          1.580000     1.000000       15.500000   0.611000
# mean       8.319637          0.527821     0.270976        2.538806   0.087467
# std        1.740552          0.179004     0.194740        1.409487   0.047051
# Q1         7.100000          0.390000     0.090000        1.900000   0.070000
# Q2         7.900000          0.520000     0.260000        2.200000   0.079000
# Q3         9.200000          0.640000     0.420000        2.600000   0.090000
# IQR        2.100000          0.250000     0.330000        0.700000   0.020000
# minN       3.950000          0.015000    -0.405000        0.850000   0.040000
# maxN      12.350000          1.015000     0.915000        3.650000   0.120000
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# ...

# %%
plt.figure()
plt.hist(df['pH'].values, bins=10)
plt.show()

# %%
plt.figure()
plt.boxplot( df['pH'].values  )
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1) #(#filas,#columnas,número de figura[primera, segunda,...])
plt.hist(df['pH'].values, bins=13)
plt.subplot(1,2,2)
plt.boxplot(df['pH'].values)
plt.show()

# %% [markdown]
# ### Correlation

# %%
dfc = df.corr() #-1 -> 1
dfc.to_csv('winequality_corr.csv')
dfc
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Absolute values

# %%
dfc = df.corr()
dfcabs = pandas.DataFrame(np.round(np.abs(dfc.values),2), index = dfc.index, columns=dfc.columns)
dfcabs.to_csv('winequality_abscorr.csv')

# %%
sns.heatmap(dfcabs, annot=True)
# Out:
# <AxesSubplot:>

# %%
#option 1
seaborn.scatterplot(data=df, x='pH', y='alcohol')
#option2
seaborn.scatterplot( x=df['pH'].values, y=df['alcohol'].values )
#option3
plt.figure()
plt.title('Correlation')
plt.xlabel('pH')
plt.ylabel('alcohol')
plt.scatter(df['pH'].values, df['alcohol'].values, color='red',s=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-5a9ebf7273f1> in <module>
#       1 #option 1
# ----> 2 seaborn.scatterplot(data=df, x='pH', y='alcohol')
#       3 #option2
#       4 seaborn.scatterplot( x=df['pH'].values, y=df['alcohol'].values )
#       5 #option3
#
# NameError: name 'seaborn' is not defined

# %%
seaborn.scatterplot( data=df, x='pH', y='alcohol', size='quality', hue='alcohol')

# %%
idx3 = df['quality'].values==3
idx4 = df['quality'].values==3
idx5 = df['quality'].values==3
idx6 = df['quality'].values==3
idx7 = df['quality'].values==3

plt.figure()
plt.title('Correlation')
plt.xlabel('pH')
plt.ylabel('alcohol')
plt.scatter(df['pH'].values[idx3], df['alcohol'].values[idx3], color='red',s=10)
plt.scatter(df['pH'].values[idx4], df['alcohol'].values[idx4], color='black',s=10)
plt.scatter(df['pH'].values[idx5], df['alcohol'].values[idx5], color='pink',s=2)
plt.scatter(df['pH'].values[idx6], df['alcohol'].values[idx6], color='blue',s=2)

plt.legend()
plt.show()

# %%
sns.countplot(data=df, x='quality')
np.unique(df['quality'].values, return_counts=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-142d2d8fda8e> in <module>
# ----> 1 sns.countplot(data=df, x='quality')
#       2 np.unique(df['quality'].values, return_counts=True)
#
# NameError: name 'sns' is not defined

# %%
sns.boxplot(data=df, x='quality', y='alcohol')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a19c6517ba8> in <module>
# ----> 1 sns.boxplot(data=df, x='quality', y='alcohol')
#
# NameError: name 'sns' is not defined

# %%
sns.catplot(data=df, x='quality', y='alcohol')

# %%
sns.catplot(data=df, x='quality', y='alcohol', kind='violin')
