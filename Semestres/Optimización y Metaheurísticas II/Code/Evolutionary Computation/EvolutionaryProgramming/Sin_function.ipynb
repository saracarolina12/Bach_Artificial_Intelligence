# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('../../data/datos.csv')
X = df['x'].values
Y = df['y'].values
plt.figure()
plt.plot(X,Y,'.')
plt.show()

# %%
def objective_function(P,X,Y):
    A,B,C = P[0],P[1],P[2]
    Yp = A*np.sin(B*X+C*np.pi)
    return np.sum(np.abs(Y-Yp))

def draw_solution(P,X,Y):
    A,B,C = P[0],P[1],P[2]
    Yp = A*np.sin(B*X+C*np.pi)
    plt.figure()
    plt.plot(X,Y,'.')
    plt.plot(X,Yp)
    plt.show()

P = [10,10,10]
print(objective_function(P,X,Y))
draw_solution(P,X,Y)
# Out:
# 643.4350369300496

# %% [markdown]
# # Scipy Differential Evolution

# %%
from scipy.optimize import differential_evolution

# %%
# P = [Z,B,C]
# f(x) = A*sin(Bx+C*pi)
bounds = [  [-100,100], # rango A
            [-100,100], # rango B
            [-100,100]] # rango C

# %%
res = differential_evolution(objective_function,bounds, args=(X,Y))
res
# Out:
#      fun: 10.650013002875095
#      jac: array([  2.60205885, 321.11631132,   2.85944816])
#  message: 'Optimization terminated successfully.'
#     nfev: 6273
#      nit: 136
#  success: True
#        x: array([ 1.99273941, -1.30977723, 65.02676831])

# %%
from matplotlib.pyplot import draw


P = res.x
print(objective_function(P,X,Y))
draw_solution(P,X,Y)
# Out:
# 10.650013002875095

# %% [markdown]
# # Evolutionary Programming

# %%
from evolutionary_programming import evolutionary_programming

# %%
evolutionary_programming(objective_function, bounds, args=(X,Y))
# Out:
# .. 1 1
# 1
# [-63.20200451 -37.10678794 -66.5677257 ] 4970.112759657716
# [[-63.20200451 -37.10678794 -66.5677257    6.93779897  11.32577595
#    15.69129749]]
# [-63.20200451 -37.10678794 -66.5677257    6.93779897  11.32577595
#   15.69129749]
# [-63.20200451 -37.10678794 -66.5677257    6.93779897  11.32577595
#   15.69129749]
# survivor
# [[-63.20200451 -37.10678794 -66.5677257    6.93779897  11.32577595
#    15.69129749]
#  [-55.04888447 -25.62790917 -61.55506478   7.30508076  10.35729357
#    10.01799497]]
