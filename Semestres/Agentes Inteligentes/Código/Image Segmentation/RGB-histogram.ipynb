# %%
import numpy as np
import skimage.color
import skimage.io
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# <span style="color:pink; font-size:3.5rem">*1. Generate Histogram*</span>.

# %%
def createHistogram(image):
    values = np.zeros([256,3])
#     print(values)
    n,m,ñ = image.shape
    for x in range(0, ñ):
        for i in range(0,n):
            for j in range(0,m):
                values[image[i,j,x],x] += 1
    return values
imgVals = createHistogram(img)
# print(imgVals)
plt.bar(range(len(imgVals)), imgVals)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_552/2219252882.py in <module>
#      10 imgVals = createHistogram(img)
#      11 # print(imgVals)
# ---> 12 plt.bar(range(len(imgVals)), imgVals)
#      13 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# ...

# %% [markdown]
# ## Load and Display Image

# %%
img = cv2.imread("../images/b.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Show Histogram

# %%
#create histogram
imgVals = createHistogram(img)
plt.bar(range(len(imgVals)), imgVals)
plt.show()
